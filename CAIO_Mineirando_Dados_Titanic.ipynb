# %%
#Importando o pandas

import pandas as pd

# %%
#importando o numpy 

import numpy as np

# %%
#importando o matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importando seaborn

import seaborn as sns
paleta_cores = ["#34495e", "#5497B0", "#89B7D0"]
sns.set(style = "dark", palette = paleta_cores, color_codes = True)

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
#Informacao dos dados 
#Survived (Sobreviveu): 0 = Não, 1 = Sim
#Pclass (Classe): Classe de ingresso 1 = 1º, 2 = 2º, 3 = 3º
#Sex (Sexo): Sexo do passageiro
#Age (Idade): Idade em anos
#Sibsp: Quantidade de irmãos / cônjuges a bordo do Titanic
#Parch: Quantidade de pais / crianças a bordo do Titanic
#Ticket (Bilhete): Número do bilhete de embarque
#Fare (Tarifa): Tarifa paga pelo Passageiro
#Cabin (Cabine): Número de cabine
#Embarked (Embarque): Porto de Embarque (C = Cherbourg, Q=Queenstown, S = Southampton)
    
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# importando base de dados grande e selecionando as colunas que deseja ver

dados = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv", usecols=['PassengerId','Survived','Name','Sex'])

# %%
dados.head(20)
# Out:
#     PassengerId  Survived                                               Name  \
# 0             1         0                            Braund, Mr. Owen Harris
# 1             2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2             3         1                             Heikkinen, Miss. Laina
# 3             4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4             5         0                           Allen, Mr. William Henry
# 5             6         0                                   Moran, Mr. James
# 6             7         0                            McCarthy, Mr. Timothy J
# 7             8         0                     Palsson, Master. Gosta Leonard
# 8             9         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9            10         1                Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1                    Sandstrom, Miss. Marguerite Rut
# ...

# %%
# Dados das pessoas com menos de 40 anos 

dados.query('Age < 40')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# verifica o tipo de dados de cada coluna

dados.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Descrive os dados estatisticos das variaveis 

# Count - conta quantidade de linhas
# mean - media
# std - desvio padrao


dados.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Descrive os dados estatisticos das variaveis na horizontal

# Count - conta quantidade de linhas
# mean - media
# std - desvio padrao

dados.describe().transpose()
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
fig, (axis1, axis2) = plt.subplots(2,1, figsize = (15,6))
sns.boxplot(data = data, x = 'Age', ax = axis1)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-3d6e45185e85> in <module>
#       1 fig, (axis1, axis2) = plt.subplots(2,1, figsize = (15,6))
# ----> 2 sns.boxplot(data = data, x = 'Age', ax = axis1)
#       3
#       4 plt.tight_layout()
#
# NameError: name 'data' is not defined
